# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2025-03-14 08:46:12.343960: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.16.2

# %%
import numpy as np

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.

# %%
# 1. Descargar el dataset
dataset_path = keras.utils.get_file(
    "auto-mpg.data",
    "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
)
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin', 'Car Name']

raw_dataset = pd.read_csv(
    dataset_path, 
    names=column_names, 
    na_values='?', 
    comment='\t', 
    sep=' ', 
    skipinitialspace=True
)

print("Forma de raw_dataset:", raw_dataset.shape)
print(raw_dataset.head())
# Out:
# '/Users/aidamarquez/.keras/datasets/auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year', 'Origin', 'Car Name']

# %%
print(type(dataset_path))  # Debería ser <class 'str'>
# Out:
# <class 'str'>

# %%
with open(dataset_path, "r") as f:
    for _ in range(5):  # Lee las primeras 5 líneas
        print(f.readline())
# Out:
# 18.0   8   307.0      130.0      3504.      12.0   70  1	"chevrolet chevelle malibu"
#
# 15.0   8   350.0      165.0      3693.      11.5   70  1	"buick skylark 320"
#
# 18.0   8   318.0      150.0      3436.      11.0   70  1	"plymouth satellite"
#
# 16.0   8   304.0      150.0      3433.      12.0   70  1	"amc rebel sst"
#
# 17.0   8   302.0      140.0      3449.      10.5   70  1	"ford torino"

# %%
import os
print(os.path.exists(dataset_path))
# Out:
# True

# %%
print("column_names:", column_names)
print("Tipo de column_names:", type(column_names))
for i, col in enumerate(column_names):
    print(f"Elemento {i}: {col} - tipo: {type(col)}")
# Out:
# column_names: ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year', 'Origin', 'Car Name']
# Tipo de column_names: <class 'list'>
# Elemento 0: MPG - tipo: <class 'str'>
# Elemento 1: Cylinders - tipo: <class 'str'>
# Elemento 2: Displacement - tipo: <class 'str'>
# Elemento 3: Horsepower - tipo: <class 'str'>
# Elemento 4: Weight - tipo: <class 'str'>
# Elemento 5: Acceleration - tipo: <class 'str'>
# Elemento 6: Model Year - tipo: <class 'str'>
# Elemento 7: Origin - tipo: <class 'str'>
# Elemento 8: Car Name - tipo: <class 'str'>

# %%
columns_index = pd.Index(['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year', 'Origin', 'Car Name'],dtype="object")
columns_index
# Out:
# Index(['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model Year', 'Origin', 'Car Name'],
#       dtype='object')

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.24.3

# %%
# 2. Limpiar o rellenar valores faltantes
# Opción A: Eliminar filas con NaN
# dataset = raw_dataset.dropna()
# print("Forma de dataset después de dropna():", dataset.shape)

# Opción B: Rellenar valores faltantes en 'Horsepower'
dataset = raw_dataset.copy()
dataset['Horsepower'] = pd.to_numeric(dataset['Horsepower'], errors='coerce')
dataset['Horsepower'].fillna(dataset['Horsepower'].median(), inplace=True)
print("Forma de dataset después de fillna():", dataset.shape)

# Eliminar la columna 'Car Name'
dataset = dataset.drop('Car Name', axis=1)
# Out:
# Forma de raw_dataset: (398, 9)
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin  Car Name
# 0          70       1       NaN
# 1          70       1       NaN
# 2          70       1       NaN
# 3          70       1       NaN
# 4          70       1       NaN
# Forma de dataset después de fillna(): (398, 9)
# /var/folders/zl/x4wcpc6n7p75fkkmssl2_0vh0000gn/T/ipykernel_23828/463306606.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Horsepower'].fillna(dataset['Horsepower'].median(), inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %%
dataset.describe(include='all')
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.304020  2970.424623
# std      7.815984    1.701004    104.269838   38.222625   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
dataset = dataset[dataset['Horsepower']!='?']
dataset['Horsepower'] = dataset['Horsepower'].astype(float)

# %%
print(dataset.dtypes)
# Out:
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# Origin            int64
# dtype: object

# %%
# se puede hacer con get_dummies
origin = dataset.pop('Origin')

dataset['USA'] = (origin == 1)*1
dataset['Europe'] = (origin == 2)*1
dataset['Japan'] = (origin == 3)*1

# %%
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  USA  Europe  Japan
# 0          70    1       0      0
# 1          70    1       0      0
# 2          70    1       0      0
# 3          70    1       0      0
# 4          70    1       0      0

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
train_dataset = dataset.sample(frac=0.8, random_state = 0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
train_dataset.columns
# Out:
# Index(['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model Year', 'USA', 'Europe', 'Japan'],
#       dtype='object')

# %%
sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
       'Acceleration', 'Model Year']], diag_kind = 'kde')

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
train_dataset.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  318.000000  318.000000    318.000000  318.000000   318.000000
# mean    23.590566    5.427673    193.061321  103.900943  2963.823899
# std      7.913617    1.682941    103.812742   38.391029   844.749805
# min     10.000000    3.000000     70.000000   46.000000  1613.000000
# 25%     17.125000    4.000000    100.250000   75.250000  2219.250000
# 50%     22.750000    4.000000    151.000000   92.000000  2792.500000
# 75%     29.000000    6.000000    259.500000  120.000000  3571.250000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year         USA      Europe       Japan
# count    318.000000  318.000000  318.000000  318.000000  318.000000
# mean      15.595912   75.946541    0.641509    0.163522    0.194969
# std        2.796282    3.705266    0.480313    0.370424    0.396801
# min        8.000000   70.000000    0.000000    0.000000    0.000000
# 25%       13.900000   73.000000    0.000000    0.000000    0.000000
# 50%       15.500000   76.000000    1.000000    0.000000    0.000000
# 75%       17.300000   79.000000    1.000000    0.000000    0.000000
# max       24.800000   82.000000    1.000000    1.000000    1.000000

# %%
train_dataset["MPG"] = pd.to_numeric(train_dataset["MPG"], errors="coerce")

# %%
train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.T
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     318.0     5.427673    1.682941     3.0     4.00     4.0
# Displacement  318.0   193.061321  103.812742    70.0   100.25   151.0
# Horsepower    318.0   103.900943   38.391029    46.0    75.25    92.0
# Weight        318.0  2963.823899  844.749805  1613.0  2219.25  2792.5
# Acceleration  318.0    15.595912    2.796282     8.0    13.90    15.5
# Model Year    318.0    75.946541    3.705266    70.0    73.00    76.0
# USA           318.0     0.641509    0.480313     0.0     0.00     1.0
# Europe        318.0     0.163522    0.370424     0.0     0.00     0.0
# Japan         318.0     0.194969    0.396801     0.0     0.00     0.0
#
#                   75%     max
# Cylinders        6.00     8.0
# Displacement   259.50   455.0
# Horsepower     120.00   230.0
# Weight        3571.25  5140.0
# Acceleration    17.30    24.8
# Model Year      79.00    82.0
# USA              1.00     1.0
# Europe           0.00     1.0
# Japan            0.00     1.0

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

label_mean = train_labels.mean()
label_std = train_labels.std()
normed_train_labels = (train_labels - label_mean) / label_std
# Si tienes un conjunto de test, haz lo mismo con él.

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     318.0     5.427673    1.682941     3.0     4.00     4.0
# Displacement  318.0   193.061321  103.812742    70.0   100.25   151.0
# Horsepower    318.0   103.900943   38.391029    46.0    75.25    92.0
# Weight        318.0  2963.823899  844.749805  1613.0  2219.25  2792.5
# Acceleration  318.0    15.595912    2.796282     8.0    13.90    15.5
# Model Year    318.0    75.946541    3.705266    70.0    73.00    76.0
# USA           318.0     0.641509    0.480313     0.0     0.00     1.0
# Europe        318.0     0.163522    0.370424     0.0     0.00     0.0
# Japan         318.0     0.194969    0.396801     0.0     0.00     0.0
#
#                   75%     max
# Cylinders        6.00     8.0
# Displacement   259.50   455.0
# Horsepower     120.00   230.0
# Weight        3571.25  5140.0
# Acceleration    17.30    24.8
# Model Year      79.00    82.0
# USA              1.00     1.0
# Europe           0.00     1.0
# Japan            0.00     1.0

# %%
def norm(x):
    # Reemplazar los valores de std que sean 0 por 1 para evitar división por cero
    std_adj = train_stats['std'].replace(0, 1)
    return (x - train_stats['mean']) / std_adj

normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

print(normed_train_data.shape)
print(normed_test_data.shape)
# Out:
# (318, 9)
# (80, 9)

# %%
normed_train_data = normed_train_data.astype('float32')
normed_test_data = normed_test_data.astype('float32')
train_labels = train_labels.astype('float32')
test_labels = test_labels.astype('float32')

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
normed_train_data.shape[1:]
# Out:
# (9,)

# %%
normed_train_data.describe()
# Out:
#           Cylinders  Displacement  Horsepower        Weight  Acceleration  \
# count  3.180000e+02  3.180000e+02  318.000000  3.180000e+02    318.000000
# mean   2.399181e-08 -5.997951e-09    0.000000 -4.498464e-09      0.000000
# std    1.000000e+00  1.000000e+00    1.000000  1.000000e+00      1.000000
# min   -1.442518e+00 -1.185416e+00   -1.508189 -1.599082e+00     -2.716433
# 25%   -8.483201e-01 -8.940263e-01   -0.746293 -8.814135e-01     -0.606488
# 50%   -8.483201e-01 -4.051653e-01   -0.309993 -2.028102e-01     -0.034300
# 75%    3.400754e-01  6.399858e-01    0.419344  7.190604e-01      0.609412
# max    1.528471e+00  2.523184e+00    3.284597  2.576119e+00      3.291545
#
#          Model Year           USA        Europe         Japan
# count  3.180000e+02  3.180000e+02  3.180000e+02  3.180000e+02
# mean   1.199590e-08  1.499488e-09  1.499488e-08 -2.998976e-09
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.604889e+00 -1.335607e+00 -4.414453e-01 -4.913511e-01
# 25%   -7.952306e-01 -1.335607e+00 -4.414453e-01 -4.913511e-01
# 50%    1.442788e-02  7.463687e-01 -4.414453e-01 -4.913511e-01
# 75%    8.240864e-01  7.463687e-01 -4.414453e-01 -4.913511e-01
# max    1.633745e+00  7.463687e-01  2.258163e+00  2.028805e+00

# %%
model = keras.Sequential([
    layers.Dense(64, activation = 'relu', kernel_initializer='he_normal',input_shape = (normed_train_data.shape[1:])),
    layers.Dense(64, activation='relu',kernel_initializer='he_normal'),
    layers.Dense(1)
])
model.compile(loss ='mse',
              optimizer = tf.keras.optimizers.RMSprop(1e-5),
              metrics = ['mae','mse'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
def build_model():
    model = keras.Sequential([
        layers.Input(shape=(normed_train_data.shape[1],)),  # Número de columnas de entrada
        layers.Dense(64, activation='relu', kernel_initializer='he_normal'),
        layers.Dense(64, activation='relu', kernel_initializer='he_normal'),
        layers.Dense(1)  # Salida lineal para regresión
    ])
    # Usamos Adam con tasa de aprendizaje moderada
    optimizer = keras.optimizers.Adam(learning_rate=0.001, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', 'mse'])
    return model

model = build_model()
model.summary()

# 6. Entrenar el modelo
EPOCHS = 100
history = model.fit(
    normed_train_data,
    train_labels,
    epochs=EPOCHS,
    validation_split=0.2,
    verbose=1
)
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,865 (19.00 KB)
#  Trainable params: 4,865 (19.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 557.4227 - mae: 22.0877 - mse: 557.4227 - val_loss: 520.7318 - val_mae: 21.4658 - val_mse: 520.7318
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 456.0600 - mae: 19.8232 - mse: 456.0600 - val_loss: 452.6374 - val_mae: 19.8173 - val_mse: 452.6374
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 445.8643 - mae: 19.4194 - mse: 445.8643 - val_loss: 386.4868 - val_mae: 18.0621 - val_mse: 386.4868
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 370.1899 - mae: 17.5440 - mse: 370.1899 - val_loss: 321.1997 - val_mae: 16.1532 - val_mse: 321.1997
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 289.6670 - mae: 14.9406 - mse: 289.6670 - val_loss: 257.9447 - val_mae: 14.1846 - val_mse: 257.9447
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 211.4688 - mae: 12.4315 - mse: 211.4688 - val_loss: 197.9594 - val_mae: 12.2158 - val_mse: 197.9594
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 192.4244 - mae: 11.8502 - mse: 192.4244 - val_loss: 143.9005 - val_mae: 10.3651 - val_mse: 143.9005
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 122.7782 - mae: 9.2283 - mse: 122.7782 - val_loss: 98.8210 - val_mae: 8.5185 - val_mse: 98.8210
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 82.2114 - mae: 7.5723 - mse: 82.2114 - val_loss: 65.6771 - val_mae: 6.6441 - val_mse: 65.6771
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 54.9900 - mae: 6.0973 - mse: 54.9900 - val_loss: 46.1707 - val_mae: 5.4889 - val_mse: 46.1707
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 41.5246 - mae: 5.0640 - mse: 41.5246 - val_loss: 33.7550 - val_mae: 4.5861 - val_mse: 33.7550
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 30.0469 - mae: 4.1495 - mse: 30.0469 - val_loss: 24.1387 - val_mae: 3.7577 - val_mse: 24.1387
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.7928 - mae: 3.6346 - mse: 22.7928 - val_loss: 17.9433 - val_mae: 3.3458 - val_mse: 17.9433
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.1114 - mae: 3.2426 - mse: 20.1114 - val_loss: 14.2179 - val_mae: 3.0933 - val_mse: 14.2179
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.6877 - mae: 3.0332 - mse: 18.6877 - val_loss: 12.1660 - val_mae: 2.8243 - val_mse: 12.1660
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.7134 - mae: 2.6163 - mse: 12.7134 - val_loss: 11.3786 - val_mae: 2.6462 - val_mse: 11.3786
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.5875 - mae: 2.5260 - mse: 12.5874 - val_loss: 11.0332 - val_mae: 2.6199 - val_mse: 11.0332
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.4464 - mae: 2.6567 - mse: 12.4464 - val_loss: 10.8081 - val_mae: 2.5422 - val_mse: 10.8081
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.3372 - mae: 2.3989 - mse: 10.3372 - val_loss: 10.5811 - val_mae: 2.4715 - val_mse: 10.5811
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.7084 - mae: 2.4848 - mse: 11.7084 - val_loss: 9.7991 - val_mae: 2.4270 - val_mse: 9.7991
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.1114 - mae: 2.3859 - mse: 10.1114 - val_loss: 9.2991 - val_mae: 2.3450 - val_mse: 9.2991
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.5799 - mae: 2.1503 - mse: 8.5799 - val_loss: 9.4986 - val_mae: 2.3378 - val_mse: 9.4986
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 10.9113 - mae: 2.3925 - mse: 10.9113 - val_loss: 9.5198 - val_mae: 2.3289 - val_mse: 9.5198
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.2600 - mae: 2.4316 - mse: 11.2600 - val_loss: 8.6967 - val_mae: 2.2423 - val_mse: 8.6967
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.7810 - mae: 2.1040 - mse: 8.7810 - val_loss: 8.4258 - val_mae: 2.1863 - val_mse: 8.4258
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.3626 - mae: 2.2016 - mse: 9.3626 - val_loss: 8.3883 - val_mae: 2.1782 - val_mse: 8.3883
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.3897 - mae: 2.3056 - mse: 10.3897 - val_loss: 8.5159 - val_mae: 2.1895 - val_mse: 8.5159
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6645 - mae: 2.2470 - mse: 9.6645 - val_loss: 8.4923 - val_mae: 2.1827 - val_mse: 8.4923
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6979 - mae: 2.1209 - mse: 8.6979 - val_loss: 7.9110 - val_mae: 2.1116 - val_mse: 7.9110
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.8742 - mae: 2.0795 - mse: 8.8742 - val_loss: 7.5959 - val_mae: 2.0661 - val_mse: 7.5959
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.8649 - mae: 2.2082 - mse: 9.8649 - val_loss: 7.7271 - val_mae: 2.0776 - val_mse: 7.7271
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.5651 - mae: 2.1641 - mse: 8.5651 - val_loss: 7.8468 - val_mae: 2.0907 - val_mse: 7.8468
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.6414 - mae: 1.9535 - mse: 7.6414 - val_loss: 7.6023 - val_mae: 2.0595 - val_mse: 7.6023
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.9729 - mae: 2.0217 - mse: 7.9729 - val_loss: 7.8672 - val_mae: 2.0841 - val_mse: 7.8672
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.2750 - mae: 2.0059 - mse: 7.2750 - val_loss: 7.6956 - val_mae: 2.0508 - val_mse: 7.6956
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.2360 - mae: 2.0980 - mse: 8.2360 - val_loss: 7.3517 - val_mae: 2.0192 - val_mse: 7.3517
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.5612 - mae: 1.9930 - mse: 7.5612 - val_loss: 7.5544 - val_mae: 2.0304 - val_mse: 7.5544
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9493 - mae: 1.9197 - mse: 6.9493 - val_loss: 7.1377 - val_mae: 1.9711 - val_mse: 7.1377
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9003 - mae: 1.9150 - mse: 6.9003 - val_loss: 7.1732 - val_mae: 1.9769 - val_mse: 7.1732
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.1868 - mae: 2.0706 - mse: 8.1868 - val_loss: 7.3517 - val_mae: 1.9974 - val_mse: 7.3517
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.9668 - mae: 2.0305 - mse: 7.9668 - val_loss: 7.0813 - val_mae: 1.9725 - val_mse: 7.0813
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.2320 - mae: 1.8766 - mse: 6.2320 - val_loss: 6.8329 - val_mae: 1.9511 - val_mse: 6.8329
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.7088 - mae: 1.9475 - mse: 6.7088 - val_loss: 6.9380 - val_mae: 1.9582 - val_mse: 6.9380
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0235 - mae: 1.9324 - mse: 7.0235 - val_loss: 7.5174 - val_mae: 2.0116 - val_mse: 7.5174
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.3282 - mae: 1.9848 - mse: 8.3282 - val_loss: 6.7240 - val_mae: 1.9098 - val_mse: 6.7240
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.9365 - mae: 2.0145 - mse: 7.9365 - val_loss: 6.6302 - val_mae: 1.8924 - val_mse: 6.6302
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.9925 - mae: 1.8680 - mse: 6.9925 - val_loss: 6.9129 - val_mae: 1.9221 - val_mse: 6.9129
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9960 - mae: 1.8892 - mse: 6.9960 - val_loss: 6.7368 - val_mae: 1.8967 - val_mse: 6.7368
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.9094 - mae: 1.8232 - mse: 5.9094 - val_loss: 6.5166 - val_mae: 1.8806 - val_mse: 6.5166
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0211 - mae: 1.7506 - mse: 6.0211 - val_loss: 7.0988 - val_mae: 1.9320 - val_mse: 7.0988
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4524 - mae: 2.0234 - mse: 7.4524 - val_loss: 6.9979 - val_mae: 1.9239 - val_mse: 6.9979
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4754 - mae: 1.8328 - mse: 6.4754 - val_loss: 6.4852 - val_mae: 1.8573 - val_mse: 6.4852
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.2495 - mae: 1.7776 - mse: 6.2495 - val_loss: 6.8407 - val_mae: 1.8828 - val_mse: 6.8407
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.8988 - mae: 1.8206 - mse: 5.8988 - val_loss: 6.5234 - val_mae: 1.8413 - val_mse: 6.5234
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7737 - mae: 1.7272 - mse: 5.7737 - val_loss: 6.8873 - val_mae: 1.8894 - val_mse: 6.8873
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8787 - mae: 1.8641 - mse: 6.8787 - val_loss: 6.4848 - val_mae: 1.8274 - val_mse: 6.4848
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0553 - mae: 1.8577 - mse: 6.0553 - val_loss: 6.9156 - val_mae: 1.9081 - val_mse: 6.9156
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.1410 - mae: 1.7986 - mse: 6.1410 - val_loss: 7.0479 - val_mae: 1.9155 - val_mse: 7.0479
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5855 - mae: 1.7366 - mse: 5.5855 - val_loss: 6.4703 - val_mae: 1.8257 - val_mse: 6.4703
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5998 - mae: 1.6991 - mse: 5.5998 - val_loss: 6.4729 - val_mae: 1.8105 - val_mse: 6.4729
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2737 - mae: 1.7196 - mse: 5.2737 - val_loss: 6.4060 - val_mae: 1.8152 - val_mse: 6.4060
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.7915 - mae: 1.8788 - mse: 6.7915 - val_loss: 6.6267 - val_mae: 1.8552 - val_mse: 6.6267
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6073 - mae: 1.7120 - mse: 5.6073 - val_loss: 6.7094 - val_mae: 1.8512 - val_mse: 6.7094
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1057 - mae: 1.6681 - mse: 5.1057 - val_loss: 6.2032 - val_mae: 1.7796 - val_mse: 6.2032
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.3956 - mae: 1.8235 - mse: 6.3956 - val_loss: 6.4178 - val_mae: 1.8032 - val_mse: 6.4178
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7634 - mae: 1.7253 - mse: 5.7634 - val_loss: 6.2833 - val_mae: 1.7978 - val_mse: 6.2833
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.0113 - mae: 1.7842 - mse: 6.0113 - val_loss: 6.4397 - val_mae: 1.8089 - val_mse: 6.4397
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1970 - mae: 1.6927 - mse: 5.1970 - val_loss: 6.9598 - val_mae: 1.8696 - val_mse: 6.9598
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3879 - mae: 1.7172 - mse: 5.3879 - val_loss: 6.3217 - val_mae: 1.7900 - val_mse: 6.3217
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.5095 - mae: 1.7008 - mse: 5.5095 - val_loss: 6.2958 - val_mae: 1.7977 - val_mse: 6.2958
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8762 - mae: 1.6086 - mse: 4.8762 - val_loss: 6.4694 - val_mae: 1.8468 - val_mse: 6.4694
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2308 - mae: 1.6632 - mse: 5.2308 - val_loss: 6.4317 - val_mae: 1.8107 - val_mse: 6.4317
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2649 - mae: 1.6084 - mse: 5.2649 - val_loss: 6.2379 - val_mae: 1.7697 - val_mse: 6.2379
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3415 - mae: 1.5415 - mse: 4.3415 - val_loss: 6.5182 - val_mae: 1.8187 - val_mse: 6.5182
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.5605 - mae: 1.7347 - mse: 5.5605 - val_loss: 6.1789 - val_mae: 1.7667 - val_mse: 6.1789
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0873 - mae: 1.6920 - mse: 5.0873 - val_loss: 6.3580 - val_mae: 1.8034 - val_mse: 6.3580
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.9601 - mae: 1.7391 - mse: 5.9601 - val_loss: 6.6906 - val_mae: 1.8267 - val_mse: 6.6906
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9396 - mae: 1.6170 - mse: 4.9396 - val_loss: 6.2094 - val_mae: 1.7726 - val_mse: 6.2094
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2749 - mae: 1.5982 - mse: 5.2749 - val_loss: 6.1137 - val_mae: 1.7605 - val_mse: 6.1137
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6814 - mae: 1.8371 - mse: 6.6814 - val_loss: 6.3699 - val_mae: 1.7913 - val_mse: 6.3699
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1977 - mae: 1.6732 - mse: 5.1977 - val_loss: 6.1646 - val_mae: 1.7721 - val_mse: 6.1646
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.4339 - mae: 1.6178 - mse: 5.4339 - val_loss: 6.2684 - val_mae: 1.8204 - val_mse: 6.2684
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9142 - mae: 1.6337 - mse: 4.9142 - val_loss: 5.9545 - val_mae: 1.7301 - val_mse: 5.9545
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0967 - mae: 1.6141 - mse: 5.0967 - val_loss: 6.4216 - val_mae: 1.7833 - val_mse: 6.4216
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2917 - mae: 1.6739 - mse: 5.2917 - val_loss: 6.4188 - val_mae: 1.7995 - val_mse: 6.4188
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.3374 - mae: 1.8109 - mse: 6.3374 - val_loss: 6.0173 - val_mae: 1.7404 - val_mse: 6.0173
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0668 - mae: 1.6324 - mse: 5.0668 - val_loss: 6.2671 - val_mae: 1.8080 - val_mse: 6.2671
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0665 - mae: 1.6410 - mse: 5.0665 - val_loss: 6.2105 - val_mae: 1.7621 - val_mse: 6.2105
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7743 - mae: 1.6570 - mse: 5.7743 - val_loss: 6.2007 - val_mae: 1.7567 - val_mse: 6.2007
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6490 - mae: 1.4972 - mse: 4.6490 - val_loss: 6.0005 - val_mae: 1.7502 - val_mse: 6.0005
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4557 - mae: 1.4751 - mse: 4.4557 - val_loss: 6.1420 - val_mae: 1.7508 - val_mse: 6.1420
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.0354 - mae: 1.5257 - mse: 4.0354 - val_loss: 6.2409 - val_mae: 1.7579 - val_mse: 6.2409
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0851 - mae: 1.5975 - mse: 5.0851 - val_loss: 6.2514 - val_mae: 1.7974 - val_mse: 6.2514
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.0646 - mae: 1.6438 - mse: 5.0646 - val_loss: 5.8995 - val_mae: 1.7045 - val_mse: 5.8995
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6126 - mae: 1.5340 - mse: 4.6126 - val_loss: 6.5654 - val_mae: 1.8176 - val_mse: 6.5654
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2191 - mae: 1.6235 - mse: 5.2191 - val_loss: 5.9886 - val_mae: 1.7246 - val_mse: 5.9886
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2261 - mae: 1.5191 - mse: 4.2261 - val_loss: 5.9637 - val_mae: 1.7216 - val_mse: 5.9637
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.4012 - mae: 1.6332 - mse: 5.4012 - val_loss: 6.2076 - val_mae: 1.7559 - val_mse: 6.2076
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8185 - mae: 1.4068 - mse: 3.8185 - val_loss: 5.9454 - val_mae: 1.7370 - val_mse: 5.9454
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5398 - mae: 1.5274 - mse: 4.5398 - val_loss: 5.9523 - val_mae: 1.7059 - val_mse: 5.9523

# %%
9*64+64
# Out:
# 640

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)
print("\nError absoluto medio en test: {:5.2f} MPG".format(mae))
# Out:
# 3/3 - 0s - 97ms/step - loss: 7.4558 - mae: 2.0125 - mse: 7.4558
#
# Error absoluto medio en test:  2.01 MPG

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,597 (57.02 KB)
#  Trainable params: 4,865 (19.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 9,732 (38.02 KB)

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
normed_train_data.describe()
# Out:
#           Cylinders  Displacement  Horsepower        Weight  Acceleration  \
# count  3.180000e+02  3.180000e+02  318.000000  3.180000e+02    318.000000
# mean   2.399181e-08 -5.997951e-09    0.000000 -4.498464e-09      0.000000
# std    1.000000e+00  1.000000e+00    1.000000  1.000000e+00      1.000000
# min   -1.442518e+00 -1.185416e+00   -1.508189 -1.599082e+00     -2.716433
# 25%   -8.483201e-01 -8.940263e-01   -0.746293 -8.814135e-01     -0.606488
# 50%   -8.483201e-01 -4.051653e-01   -0.309993 -2.028102e-01     -0.034300
# 75%    3.400754e-01  6.399858e-01    0.419344  7.190604e-01      0.609412
# max    1.528471e+00  2.523184e+00    3.284597  2.576119e+00      3.291545
#
#          Model Year           USA        Europe         Japan
# count  3.180000e+02  3.180000e+02  3.180000e+02  3.180000e+02
# mean   1.199590e-08  1.499488e-09  1.499488e-08 -2.998976e-09
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.604889e+00 -1.335607e+00 -4.414453e-01 -4.913511e-01
# 25%   -7.952306e-01 -1.335607e+00 -4.414453e-01 -4.913511e-01
# 50%    1.442788e-02  7.463687e-01 -4.414453e-01 -4.913511e-01
# 75%    8.240864e-01  7.463687e-01 -4.414453e-01 -4.913511e-01
# max    1.633745e+00  7.463687e-01  2.258163e+00  2.028805e+00

# %%
normed_train_data = normed_train_data.astype('float32')

# %%
history = model.fit(
    normed_train_data,
    train_labels,
    epochs = 1000,
    validation_split = 0.2,
    verbose = 0
)

# %% [markdown]
# Visualice el progreso de entrenamiento del modelo usando las estadísticas almacenadas en el objeto `history`.

# %%
print(history.history.keys())   # Verifica qué métricas se están registrando
print(history.history)            # Imprime el diccionario completo para detectar si desde el inicio hay NaN
# Out:
# dict_keys(['loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse'])
# {'loss': [4.83695125579834, 4.847259044647217, 4.7637176513671875, 4.78264856338501, 4.7278008460998535, 4.797324180603027, 4.651299476623535, 4.605808734893799, 4.65397310256958, 4.687533378601074, 4.600380897521973, 4.52574348449707, 4.553622245788574, 4.471933364868164, 4.988652229309082, 4.576934337615967, 4.5492262840271, 4.513468265533447, 4.415824890136719, 4.452078342437744, 4.398324012756348, 4.352167129516602, 4.360959529876709, 4.405106544494629, 4.384188175201416, 4.441201686859131, 4.329049110412598, 4.3364739418029785, 4.356386661529541, 4.236321926116943, 4.189651966094971, 4.244685649871826, 4.172711372375488, 4.240164756774902, 4.151778697967529, 4.1808085441589355, 4.150759220123291, 4.101990222930908, 4.115645885467529, 4.096656322479248, 4.105757236480713, 4.261567115783691, 4.079598903656006, 4.104158878326416, 3.998255729675293, 4.185110092163086, 4.019686698913574, 4.032304763793945, 3.9380006790161133, 3.991428852081299, 4.005960941314697, 4.077297687530518, 3.8971681594848633, 3.9300296306610107, 3.9354312419891357, 3.9020700454711914, 4.02284049987793, 3.997070074081421, 3.9117379188537598, 3.948453664779663, 3.8201310634613037, 3.822972059249878, 3.8172452449798584, 3.7533693313598633, 3.834587574005127, 3.8052940368652344, 3.901819944381714, 3.7666378021240234, 3.7608067989349365, 3.797921895980835, 3.7947311401367188, 3.752596378326416, 3.691096782684326, 3.660578727722168, 3.7879836559295654, 3.7588770389556885, 3.65256929397583, 3.856374979019165, 3.6885077953338623, 3.688754081726074, 3.612200975418091, 3.584204912185669, 3.615804672241211, 3.6144556999206543, 3.6073341369628906, 3.5359957218170166, 3.5604052543640137, 3.5804443359375, 3.653313636779785, 3.57034969329834, 3.5457003116607666, 3.4986677169799805, 3.5557384490966797, 3.5309808254241943, 3.531580924987793, 3.4878499507904053, 3.512315273284912, 3.4394145011901855, 3.430015802383423, 3.52923583984375, 3.4479551315307617, 3.423893451690674, 3.4596199989318848, 3.392627477645874, 3.4099481105804443, 3.417365789413452, 3.384650468826294, 3.338878631591797, 3.359513282775879, 3.3978822231292725, 3.3604393005371094, 3.323864698410034, 3.3708934783935547, 3.400840997695923, 3.286426305770874, 3.323139190673828, 3.2928383350372314, 3.291440725326538, 3.279601573944092, 3.3576712608337402, 3.282456636428833, 3.306144952774048, 3.270953416824341, 3.308922290802002, 3.242762804031372, 3.2715494632720947, 3.3595457077026367, 3.2235500812530518, 3.2572429180145264, 3.193485736846924, 3.2047293186187744, 3.1907236576080322, 3.1793837547302246, 3.104555368423462, 3.1919095516204834, 3.134566307067871, 3.227684259414673, 3.1563303470611572, 3.336568593978882, 3.2542362213134766, 3.125833511352539, 3.116208076477051, 3.0951530933380127, 3.0980589389801025, 3.201663017272949, 3.0656068325042725, 3.063427209854126, 3.475597858428955, 3.4872758388519287, 3.261535406112671, 3.101195812225342, 3.199568271636963, 3.0078587532043457, 3.1714072227478027, 3.051473617553711, 3.070770025253296, 3.041836738586426, 3.1007301807403564, 3.094602108001709, 3.0586061477661133, 3.0216615200042725, 3.009615421295166, 2.9312222003936768, 3.0238444805145264, 3.1227338314056396, 3.116000175476074, 2.9923477172851562, 3.0081608295440674, 2.9903664588928223, 2.9470105171203613, 3.004610300064087, 2.948007822036743, 2.947129726409912, 2.879526376724243, 2.8931150436401367, 2.9277822971343994, 2.956907272338867, 2.9079675674438477, 2.9369888305664062, 2.9605677127838135, 2.879894971847534, 2.9249329566955566, 2.830678939819336, 2.836738348007202, 2.839071273803711, 2.8338253498077393, 2.848541259765625, 2.8514437675476074, 2.7825980186462402, 2.871100425720215, 2.7780539989471436, 2.7957210540771484, 2.818833589553833, 2.785362958908081, 2.762887477874756, 2.7609074115753174, 2.789137840270996, 2.7217204570770264, 2.753312349319458, 2.7659926414489746, 2.8197522163391113, 2.745358943939209, 2.73897123336792, 2.6862411499023438, 2.7454185485839844, 2.737893581390381, 2.728690 ...

# %%
df_hist = pd.DataFrame(history.history)
df_hist['epoch'] = history.epoch
df_hist
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 0    4.836951  1.576056  4.836951  5.959702  1.721858  5.959702      0
# 1    4.847259  1.563539  4.847259  6.068265  1.735311  6.068265      1
# 2    4.763718  1.543775  4.763718  6.179142  1.774842  6.179142      2
# 3    4.782649  1.554742  4.782649  6.097148  1.750203  6.097148      3
# 4    4.727801  1.566488  4.727801  6.489132  1.769051  6.489132      4
# ..        ...       ...       ...       ...       ...       ...    ...
# 995  0.872618  0.601820  0.872618  6.928560  1.983031  6.928560    995
# 996  0.911497  0.607286  0.911497  7.622926  2.055254  7.622926    996
# 997  0.836038  0.565786  0.836038  7.120768  1.985987  7.120768    997
# 998  0.750383  0.507943  0.750383  7.124206  2.012053  7.124206    998
# 999  0.868464  0.561331  0.868464  7.470056  2.019655  7.470056    999
#
# [1000 rows x 7 columns]

# %%
df_hist.head(50)
# Out:
#         loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 0   4.836951  1.576056  4.836951  5.959702  1.721858  5.959702      0
# 1   4.847259  1.563539  4.847259  6.068265  1.735311  6.068265      1
# 2   4.763718  1.543775  4.763718  6.179142  1.774842  6.179142      2
# 3   4.782649  1.554742  4.782649  6.097148  1.750203  6.097148      3
# 4   4.727801  1.566488  4.727801  6.489132  1.769051  6.489132      4
# 5   4.797324  1.562522  4.797324  5.816052  1.693764  5.816052      5
# 6   4.651299  1.535162  4.651299  6.134051  1.747334  6.134051      6
# 7   4.605809  1.537642  4.605809  5.998344  1.711911  5.998344      7
# 8   4.653973  1.531608  4.653973  6.036175  1.736648  6.036175      8
# 9   4.687533  1.549762  4.687533  6.270323  1.745522  6.270323      9
# 10  4.600381  1.545825  4.600381  5.976444  1.720296  5.976444     10
# 11  4.525743  1.509832  4.525743  5.959463  1.730361  5.959463     11
# 12  4.553622  1.507533  4.553622  6.169269  1.746933  6.169269     12
# 13  4.471933  1.504613  4.471933  5.776762  1.688746  5.776762     13
# 14  4.988652  1.542505  4.988652  5.738368  1.718338  5.738368     14
# 15  4.576934  1.531590  4.576934  6.531883  1.761565  6.531883     15
# 16  4.549226  1.542547  4.549226  6.015960  1.719430  6.015960     16
# 17  4.513468  1.506164  4.513468  5.768383  1.690433  5.768383     17
# 18  4.415825  1.485391  4.415825  6.282557  1.766488  6.282557     18
# 19  4.452078  1.512700  4.452078  5.860929  1.698040  5.860929     19
# 20  4.398324  1.484327  4.398324  6.179364  1.722891  6.179364     20
# 21  4.352167  1.472506  4.352167  5.970256  1.725164  5.970256     21
# 22  4.360960  1.459353  4.360960  6.028490  1.757602  6.028490     22
# 23  4.405107  1.452653  4.405107  6.009664  1.722126  6.009664     23
# 24  4.384188  1.485182  4.384188  6.148997  1.726547  6.148997     24
# 25  4.441202  1.479375  4.441202  5.654148  1.679552  5.654148     25
# 26  4.329049  1.473885  4.329049  6.228357  1.750543  6.228357     26
# 27  4.336474  1.469375  4.336474  5.710572  1.724216  5.710572     27
# 28  4.356387  1.453678  4.356387  5.784495  1.720815  5.784495     28
# 29  4.236322  1.444905  4.236322  5.887087  1.713894  5.887087     29
# 30  4.189652  1.429329  4.189652  5.824113  1.701353  5.824113     30
# 31  4.244686  1.437311  4.244686  5.795408  1.693410  5.795408     31
# 32  4.172711  1.439113  4.172711  5.955290  1.709867  5.955290     32
# 33  4.240165  1.472034  4.240165  6.175097  1.718309  6.175097     33
# 34  4.151779  1.436019  4.151779  5.741683  1.674256  5.741683     34
# 35  4.180809  1.431317  4.180809  6.019315  1.733362  6.019315     35
# 36  4.150759  1.454927  4.150759  5.983288  1.729588  5.983288     36
# 37  4.101990  1.403956  4.101990  5.888202  1.713176  5.888202     37
# 38  4.115646  1.416650  4.115646  5.889373  1.698915  5.889373     38
# 39  4.096656  1.391479  4.096656  5.768631  1.699934  5.768631     39
# 40  4.105757  1.430561  4.105757  5.951498  1.697649  5.951498     40
# 41  4.261567  1.402293  4.261567  5.735420  1.716408  5.735420     41
# 42  4.079599  1.411798  4.079599  6.172069  1.723431  6.172069     42
# 43  4.104159  1.412803  4.104159  5.729330  1.689287  5.729330     43
# 44  3.998256  1.377246  3.998256  6.076825  1.723486  6.076825     44
# 45  4.185110  1.457378  4.185110  6.378725  1.752726  6.378725     45
# 46  4.019687  1.379910  4.019687  5.677897  1.681292  5.677897     46
# 47  4.032305  1.388426  4.032305  6.118468  1.722323  6.118468     47
# 48  3.938001  1.386075  3.938001  5.797066  1.687610  5.797066     48
# 49  3.991429  1.377748  3.991429  5.802184  1.689156  5.802184     49

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.plot(df_hist['epoch'], df_hist['mae'], label=['Train Error'] )
plt.plot(df_hist['epoch'], df_hist['val_mae'], label=['Val Error'] )
plt.ylim([0,5])
plt.legend()

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.plot(df_hist['epoch'], df_hist['mse'], label=['Train Error'] )
plt.plot(df_hist['epoch'], df_hist['val_mse'], label=['Val Error'] )
plt.ylim([0,20])
plt.legend()

# %%
def plot_history(history):
    df_hist = pd.DataFrame(history.history)
    df_hist['epoch'] = history.epoch
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.plot(df_hist['epoch'], df_hist['mae'], label=['Train Error'] )
    plt.plot(df_hist['epoch'], df_hist['val_mae'], label=['Val Error'] )
    plt.legend()
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.plot(df_hist['epoch'], df_hist['mse'], label=['Train Error'] )
    plt.plot(df_hist['epoch'], df_hist['val_mse'], label=['Val Error'] )
    plt.ylim([0,20])
    plt.legend()

# %%
plot_history(history)

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %% [raw]
# Podemos observar que no conseguimos bajar el error en validación a partir de la epoch 50 aprox, y que por lo tanto podríamos estar ante un problema de overfitting.
# Lo interesante sería entrenar mi modelo con 50 epochs.

# %% [markdown]
# Añade un early stopping al modelo. Pon el argumento `callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]` dentro del fit().
#
# Después del entrenamiento utiliza la función del apartado anterior `plot_history(history)`.

# %%
model = keras.Sequential([
    layers.Dense(64, activation = 'relu', input_shape = (normed_train_data.shape[1:])),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(loss ='mse',
              optimizer = tf.keras.optimizers.RMSprop(0.001),
              metrics = ['mae','mse'])

history = model.fit(
    normed_train_data,
    train_labels,
    epochs = 1000,
    validation_split = 0.2,
    verbose = 0,
    callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
)

plot_history(history)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Interpreta el gráfico

# %% [raw]
# Como habíamos observado en el ejercicio anterior, como a partir aprox de la epoch 50 no baja su val loss, para de iterar.

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels)
mae
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.4241 - mae: 1.7463 - mse: 5.4241
# 1.9358093738555908

# %%
model.save("my_keras_model_MAE_1_96.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de train y llama a` model.predict`.

# %%
result_10 = model.predict(normed_train_data[:10])
result_10
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# array([[13.053586],
#        [23.16636 ],
#        [13.019098],
#        [20.198872],
#        [17.48339 ],
#        [30.49729 ],
#        [34.757965],
#        [20.066227],
#        [15.601147],
#        [26.608007]], dtype=float32)

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
# Out:
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
error = test_predictions - test_labels

plt.hist(error)
# Out:
# (array([ 1.,  0.,  0.,  4.,  8., 22., 21., 17.,  5.,  2.]),
#  array([-10.50557137,  -8.79782295,  -7.09007406,  -5.38232565,
#          -3.674577  ,  -1.96682835,  -0.25907975,   1.44866884,
#           3.15641737,   4.86416626,   6.57191467]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# ## Conclusion
#
# Este cuaderno introdujo algunas técnicas para manejar un problema de regresión.
#
# * El error cuadrático medio (MSE) es una función de pérdida común utilizada para problemas de regresión (se utilizan diferentes funciones de pérdida para problemas de clasificación).
# * Del mismo modo, las métricas de evaluación utilizadas para la regresión difieren de la clasificación. Una métrica de regresión común es el error absoluto medio (MAE).
# * Cuando las características de datos de entrada numéricos tienen valores con diferentes rangos, cada característica debe escalarse independientemente al mismo rango.
# * Si no hay muchos datos de entrenamiento, una técnica es preferir una red pequeña con pocas capas ocultas para evitar el sobreajuste.
# * La detención temprana es una técnica útil para evitar el sobreajuste.

# %%
model_loaded = keras.models.load_model("my_keras_model_MAE_1_96.h5")

test_predictions = model_loaded.predict(normed_test_data).flatten()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 model_loaded = keras.models.load_model("my_keras_model_MAE_1_96.h5")
#       3 test_predictions = model_loaded.predict(normed_test_data).flatten()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/legacy/saving/legacy_h5_format.py:155, in load_model_from_hdf5(filepath, custom_objects, compile)
#     151 training_config = json_utils.decode(training_config)
#     153 # Compile model.
#     154 model.compile(
# --> 155     **saving_utils.compile_args_from_training_config(
#     156         training_config, custom_objects
#     157     )
#     158 )
#     159 saving_utils.try_build_compiled_arguments(model)
#     161 # Set optimizer weights.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/legacy/saving/saving_utils.py:146, in compile_args_from_training_config(training_config, custom_objects)
#     144 loss_config = training_config.get("loss", None)
#     145 if loss_config is not None:
# --> 146     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     147     # Ensure backwards compatibility for losses in legacy H5 files
#     148     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/legacy/saving/saving_utils.py:205, in _deserialize_nested_config(deserialize_fn, config)
#     203     return None
#     204 if _is_single_object(config):
# --> 205     return deserialize_fn(config)
#     206 elif isinstance(config, dict):
#     207     return {
#     208         k: _deserialize_nested_config(deserialize_fn, v)
#     209         for k, v in config.items()
#     210     }
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/losses/__init__.py:155, in deserialize(name, custom_objects)
#     142 @keras_export("keras.losses.deserialize")
#     143 def deserialize(name, custom_objects=None):
#     144     """Deserializes a serialized loss class/function instance.
#     145
#     146     Args:
#    (...)    153         A Keras `Loss` instance or a loss function.
#     154     """
# --> 155     return serialization_lib.deserialize_keras_object(
#     156         name,
#     157         module_objects=ALL_OBJECTS_DICT,
#     158         custom_objects=custom_objects,
#     159     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:575, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     573             return config
#     574         if isinstance(module_objects[config], types.FunctionType):
# --> 575             return deserialize_keras_object(
#     576                 serialize_with_public_fn(
#     577                     module_objects[config], config, fn_module_name
#     578                 ),
#     579                 custom_objects=custom_objects,
#     580             )
#     581         return deserialize_keras_object(
#     582             serialize_with_public_class(
#     583                 module_objects[config], inner_config=inner_config
#     584             ),
#     585             custom_objects=custom_objects,
#     586         )
#     588 if isinstance(config, PLAIN_TYPES):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:678, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     676 if class_name == "function":
#     677     fn_name = inner_config
# --> 678     return _retrieve_class_or_fn(
#     679         fn_name,
#     680         registered_name,
#     681         module,
#     682         obj_type="function",
#     683         full_config=config,
#     684         custom_objects=custom_objects,
#     685     )
#     687 # Below, handling of all classes.
#     688 # First, is it a shared object?
#     689 if "shared_object_id" in config:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:810, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     803         except ModuleNotFoundError:
#     804             raise TypeError(
#     805                 f"Could not deserialize {obj_type} '{name}' because "
#     806                 f"its parent module {module} cannot be imported. "
#     807                 f"Full object config: {full_config}"
#     808             )
# --> 810 raise TypeError(
#     811     f"Could not locate {obj_type} '{name}'. "
#     812     "Make sure custom classes are decorated with "
#     813     "`@keras.saving.register_keras_serializable()`. "
#     814     f"Full object config: {full_config}"
#     815 )
#
# TypeError: Could not locate function 'mse'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': 'keras.metrics', 'class_name': 'function', 'config': 'mse', 'registered_name': 'mse'}

# %%
test_predictions
# Out:
# array([15.959854 , 11.809258 , 11.608888 , 23.739529 , 21.456018 ,
#        13.452995 , 13.459328 , 13.185891 , 19.566277 , 30.197691 ,
#        25.139772 , 24.434137 , 14.758896 , 27.099537 , 12.689086 ,
#        14.1606865, 14.756001 , 13.51071  , 18.882006 , 12.879957 ,
#        13.7637005, 26.122679 , 19.916225 , 20.633533 , 29.98501  ,
#        24.111109 , 16.20769  , 22.777466 , 17.006292 , 18.20529  ,
#        28.178366 , 21.969866 , 18.92736  , 21.148462 , 27.137497 ,
#        15.942303 , 19.165396 , 31.352602 , 30.45122  , 17.699923 ,
#        31.231674 , 29.20478  , 15.917363 , 36.987144 , 35.3077   ,
#        36.589806 , 20.384377 , 22.27115  , 20.109816 , 25.79674  ,
#        31.362179 , 18.753128 , 32.70923  , 19.180439 , 18.488049 ,
#        18.481604 , 33.337845 , 35.812485 , 22.335962 , 24.958067 ,
#        39.508484 , 33.77723  , 27.741447 , 28.67013  , 32.379013 ,
#        40.749245 , 37.772156 , 35.85453  , 33.42369  , 31.257288 ,
#        23.182585 , 23.119347 , 29.98371  , 30.534584 , 35.97303  ,
#        36.984154 , 39.375183 , 30.357042 ], dtype=float32)

# %% [markdown]
# ### Importing Relevant Packages

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
sns.set()

# %% [markdown]
# ### Loading and Transforming the Data

# %%
raw_csv_data = pd.read_csv("https://raw.githubusercontent.com/MaddoSaru/curso-series-temporales/master/3.%20Caracter%C3%ADsticas%20fundamentales/Python/Index2018.csv") 
df_comp=raw_csv_data.copy()
df_comp.date = pd.to_datetime(df_comp.date, dayfirst = True)
df_comp.set_index("date", inplace=True)
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')
# Out:
# C:\Users\yporq\AppData\Local\Temp\ipykernel_49508\521637752.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_comp=df_comp.fillna(method='ffill')

# %% [markdown]
# ### Removing Surplus Data

# %%
df_comp['market_value']=df_comp.spx

# %%
del df_comp['spx']
del df_comp['dax']
del df_comp['ftse']
del df_comp['nikkei']
size = int(len(df_comp)*0.8)
df, df_test = df_comp.iloc[:size], df_comp.iloc[size:]

# %% [markdown]
# ### White Noise

# %%
wn = np.random.normal(loc = df.market_value.mean(), scale = df.market_value.std(), size = len(df))

# %%
df['wn'] = wn
# Out:
# C:\Users\yporq\AppData\Local\Temp\ipykernel_49508\672873062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wn'] = wn

# %%
df.describe()
# Out:
#        market_value           wn
# count   5021.000000  5021.000000
# mean    1091.651926  1088.960503
# std      292.559287   293.623041
# min      438.920000    12.154877
# 25%      914.620000   892.730188
# 50%     1144.650000  1092.030287
# 75%     1316.280729  1290.188282
# max     1570.252238  2185.058102

# %%
df.wn.plot(figsize = (20,5))
plt.title("White Noise Time-Series", size= 24)
plt.show()

# %%
df.market_value.plot(figsize=(20,5))
plt.title("S&P Prices", size = 24)
plt.ylim(0,2300)
plt.show()

# %% [markdown]
# ### Random Walk

# %%
rw = pd.read_csv("RandWalk.csv")

# %%
rw.head()
# Out:
#          date        price
# 0  07/01/1994  1122.139662
# 1  08/01/1994  1135.238562
# 2  09/01/1994  1109.897831
# 3  10/01/1994  1080.347860
# 4  11/01/1994  1082.095245

# %%
rw.date = pd.to_datetime(rw.date, dayfirst = True)

# %%
rw.set_index("date", inplace = True)

# %%
rw.head()
# Out:
#                   price
# date
# 1994-01-07  1122.139662
# 1994-01-08  1135.238562
# 1994-01-09  1109.897831
# 1994-01-10  1080.347860
# 1994-01-11  1082.095245

# %%
rw = rw.asfreq('b')

# %%
rw.describe()
# Out:
#              price
# count  5021.000000
# mean   1269.944293
# std     444.216793
# min     585.483034
# 25%     931.550429
# 50%    1156.363045
# 75%    1488.362029
# max    2715.508720

# %%
df['rw'] = rw.price
# Out:
# C:\Users\yporq\AppData\Local\Temp\ipykernel_49508\818302766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rw'] = rw.price

# %%
df.head()
# Out:
#             market_value           wn           rw
# date
# 1994-01-07        469.90   610.909480  1122.139662
# 1994-01-10        475.27  1024.232805  1080.347860
# 1994-01-11        474.13  1374.765317  1082.095245
# 1994-01-12        474.17  1210.753690  1083.639265
# 1994-01-13        472.47  1468.806799  1067.146255

# %%
df.rw.plot(figsize = (20,5))
plt.title("Random Walk", size = 24)
plt.show()

# %%
df.rw.plot(figsize = (20,5))
df.market_value.plot()
plt.title("Random Walk vs S&P", size = 24)
plt.legend() 
plt.show()

# %% [markdown]
# ### Stationarity

# %%
sts.adfuller(df.market_value)
# Out:
# (-1.7369847452352436,
#  0.4121645696770623,
#  18,
#  5002,
#  {'1%': -3.431658008603046,
#   '5%': -2.862117998412982,
#   '10%': -2.567077669247375},
#  39904.880607487445)

# %%
sts.adfuller(df.wn)
# Out:
# (-26.600327466035107,
#  0.0,
#  6,
#  5014,
#  {'1%': -3.4316548765428174,
#   '5%': -2.8621166146845334,
#   '10%': -2.5670769326348926},
#  70848.32785015742)

# %%
sts.adfuller(df.rw)
# Out:
# (-1.3286073927689719,
#  0.6159849181617385,
#  24,
#  4996,
#  {'1%': -3.4316595802782865,
#   '5%': -2.8621186927706463,
#   '10%': -2.567078038881065},
#  46299.333497595144)

# %% [markdown]
# ### Seasonality

# %%
s_dec_additive = seasonal_decompose(df.market_value, model = "additive")
s_dec_additive.plot()
plt.show()

# %%
s_dec_multiplicative = seasonal_decompose(df.market_value, model = "multiplicative")
s_dec_multiplicative.plot()
plt.show()

# %% [markdown]
# ### ACF

# %%
sgt.plot_acf(df.market_value, lags = 40, zero = False)
plt.title("ACF S&P", size = 24)
plt.show()

# %%
sgt.plot_acf(df.wn, lags = 40, zero = False)
plt.title("ACF WN", size = 24)
plt.show()

# %%
sgt.plot_acf(df.rw, lags = 40, zero = False)
plt.title("ACF RW", size = 24)
plt.show()

# %% [markdown]
# ### PACF

# %%
sgt.plot_pacf(df.market_value, lags = 40, zero = False, method = ('ols'))
plt.title("PACF S&P", size = 24)
plt.show()

# %%
sgt.plot_pacf(df.wn, lags = 40, zero = False, method = ('ols'))
plt.title("PACF WN", size = 24)
plt.show()

# %%
sgt.plot_pacf(df.rw, lags = 40, zero = False, method = ('ols'))
plt.title("PACF RW", size = 24)
plt.show()
